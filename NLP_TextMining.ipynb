# %%
import os
import nltk
import nltk.corpus

# %%
DeepLearning= """Deep learning is an artificial intelligence (AI) function that imitates the workings of the human brain in processing data and creating patterns for use in decision making. Deep learning is a subset of machine learning in artificial intelligence that has networks capable of learning unsupervised from data that is unstructured or unlabeled. 
Also known as deep neural learning or deep neural network. 

Deep neural networks are generally interpreted in terms of the universal approximation theorem or probabilistic inference. The classic universal approximation theorem concerns the capacity of feedforward neural networks with a single hidden layer of finite size to approximate continuous functions. In 1989, the first proof was published by George Cybenko for sigmoid activation functions[18][citation needed] and was generalised to feed-forward multi-layer architectures 
in 1991 by Kurt Hornik. Recent work also showed that universal approximation also holds for non-bounded activation functions such as the rectified linear unit."""

# %%
type(DeepLearning)
len(DeepLearning)
# Out:
# 1036

# %% [markdown]
# ## Tokenize the text

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
DL_tokens= word_tokenize(DeepLearning)
DL_tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\maede\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Deep',
#  'learning',
#  'is',
#  'an',
#  'artificial',
#  'intelligence',
#  '(',
#  'AI',
#  ')',
#  'function',
#  'that',
#  'imitates',
#  'the',
#  'workings',
#  'of',
#  'the',
#  'human',
#  'brain',
#  'in',
#  'processing',
#  'data',
#  'and',
#  'creating',
#  'patterns',
#  'for',
#  'use',
#  'in',
#  'decision',
#  'making',
#  '.',
#  'Deep',
#  'learning',
#  'is',
#  'a',
#  'subset',
#  'of',
#  'machine',
#  'learning',
#  'in',
#  'artificial',
#  'intelligence',
#  'that',
#  'has',
#  'networks',
#  'capable',
#  'of',
#  'learning',
#  'unsupervised',
#  'from',
#  'data',
#  'that',
#  'is',
#  'unstructured',
#  'or',
#  'unlabeled',
#  '.',
#  'Also',
#  'known',
#  'as',
#  'deep',
#  'neural',
#  'learning',
#  'or',
#  'deep',
#  'neural',
#  'network',
#  '.',
#  'Deep',
#  'neural',
#  'networks',
#  'are',
#  'generally',
#  'interpreted',
#  'in',
#  'terms',
#  'of',
#  'the',
#  'universal',
#  'approximation',
#  'theorem',
#  'or',
#  'probabilistic',
#  'inference',
#  '.',
#  'The',
#  'classic',
#  'universal',
#  'approximation',
#  'theorem',
#  'concerns',
#  'the',
#  'capacity',
#  'of',
#  'feedforward',
#  'neural',
#  'networks',
#  'with',
#  'a',
#  'single',
#  'hidden',
#  'layer',
#  'of',
#  'finite',
#  'size',
#  'to',
#  'approximate',
#  'continuous',
#  'functions',
#  '.',
#  'In',
#  '1989',
#  ',',
#  'the',
#  'first',
#  'proof',
#  'was',
#  'published',
#  'by',
#  'George',
#  'Cybenko',
#  'for',
#  'sigmoid',
#  'activation',
#  'functions',
#  '[',
#  '18',
#  ']',
#  '[',
#  'citation',
#  'needed',
#  ']',
#  'and',
#  'was',
#  'generalised',
#  'to',
#  'feed-forward',
#  'multi-layer',
#  'architectures',
#  'in',
#  '1991',
#  'by',
#  'Kurt',
#  'Hornik',
#  '.',
#  'Recent',
#  'work',
#  'also',
#  'showed',
#  'that',
#  'universal',
#  'approximation',
#  'also',
#  'holds',
#  'for',
#  'non-bounded',
#  'activation',
#  'functions',
#  'such',
#  'as',
#  'the',
#  'rectified',
#  'linear',
#  'unit',
#  '.']

# %%
len(DL_tokens)
# Out:
# 164

# %%
from nltk.probability import FreqDist

# %%
count=FreqDist()

# %%
for words in DL_tokens:
    count[words.lower()]+=1
count
# Out:
# FreqDist({'the': 7, '.': 7, 'of': 6, 'in': 6, 'deep': 5, 'learning': 5, 'that': 4, 'neural': 4, 'is': 3, 'for': 3, ...})

# %%
count_top15=count.most_common(15)
count_top15
# Out:
# [('the', 7),
#  ('.', 7),
#  ('of', 6),
#  ('in', 6),
#  ('deep', 5),
#  ('learning', 5),
#  ('that', 4),
#  ('neural', 4),
#  ('is', 3),
#  ('for', 3),
#  ('networks', 3),
#  ('or', 3),
#  ('also', 3),
#  ('universal', 3),
#  ('approximation', 3)]

# %%
from nltk import blankline_tokenize
DL_blnklin=blankline_tokenize(DeepLearning)
len(DL_blnklin)
# Out:
# 2

# %%
from nltk.util import ngrams, bigrams, trigrams

# %%
DL_bigrams= list(nltk.bigrams(DL_tokens))

# %%
DL_trigrams= list(nltk.trigrams(DL_tokens))
DL_trigrams
# Out:
# [('Deep', 'learning', 'is'),
#  ('learning', 'is', 'an'),
#  ('is', 'an', 'artificial'),
#  ('an', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', '('),
#  ('intelligence', '(', 'AI'),
#  ('(', 'AI', ')'),
#  ('AI', ')', 'function'),
#  (')', 'function', 'that'),
#  ('function', 'that', 'imitates'),
#  ('that', 'imitates', 'the'),
#  ('imitates', 'the', 'workings'),
#  ('the', 'workings', 'of'),
#  ('workings', 'of', 'the'),
#  ('of', 'the', 'human'),
#  ('the', 'human', 'brain'),
#  ('human', 'brain', 'in'),
#  ('brain', 'in', 'processing'),
#  ('in', 'processing', 'data'),
#  ('processing', 'data', 'and'),
#  ('data', 'and', 'creating'),
#  ('and', 'creating', 'patterns'),
#  ('creating', 'patterns', 'for'),
#  ('patterns', 'for', 'use'),
#  ('for', 'use', 'in'),
#  ('use', 'in', 'decision'),
#  ('in', 'decision', 'making'),
#  ('decision', 'making', '.'),
#  ('making', '.', 'Deep'),
#  ('.', 'Deep', 'learning'),
#  ('Deep', 'learning', 'is'),
#  ('learning', 'is', 'a'),
#  ('is', 'a', 'subset'),
#  ('a', 'subset', 'of'),
#  ('subset', 'of', 'machine'),
#  ('of', 'machine', 'learning'),
#  ('machine', 'learning', 'in'),
#  ('learning', 'in', 'artificial'),
#  ('in', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', 'that'),
#  ('intelligence', 'that', 'has'),
#  ('that', 'has', 'networks'),
#  ('has', 'networks', 'capable'),
#  ('networks', 'capable', 'of'),
#  ('capable', 'of', 'learning'),
#  ('of', 'learning', 'unsupervised'),
#  ('learning', 'unsupervised', 'from'),
#  ('unsupervised', 'from', 'data'),
#  ('from', 'data', 'that'),
#  ('data', 'that', 'is'),
#  ('that', 'is', 'unstructured'),
#  ('is', 'unstructured', 'or'),
#  ('unstructured', 'or', 'unlabeled'),
#  ('or', 'unlabeled', '.'),
#  ('unlabeled', '.', 'Also'),
#  ('.', 'Also', 'known'),
#  ('Also', 'known', 'as'),
#  ('known', 'as', 'deep'),
#  ('as', 'deep', 'neural'),
#  ('deep', 'neural', 'learning'),
#  ('neural', 'learning', 'or'),
#  ('learning', 'or', 'deep'),
#  ('or', 'deep', 'neural'),
#  ('deep', 'neural', 'network'),
#  ('neural', 'network', '.'),
#  ('network', '.', 'Deep'),
#  ('.', 'Deep', 'neural'),
#  ('Deep', 'neural', 'networks'),
#  ('neural', 'networks', 'are'),
#  ('networks', 'are', 'generally'),
#  ('are', 'generally', 'interpreted'),
#  ('generally', 'interpreted', 'in'),
#  ('interpreted', 'in', 'terms'),
#  ('in', 'terms', 'of'),
#  ('terms', 'of', 'the'),
#  ('of', 'the', 'universal'),
#  ('the', 'universal', 'approximation'),
#  ('universal', 'approximation', 'theorem'),
#  ('approximation', 'theorem', 'or'),
#  ('theorem', 'or', 'probabilistic'),
#  ('or', 'probabilistic', 'inference'),
#  ('probabilistic', 'inference', '.'),
#  ('inference', '.', 'The'),
#  ('.', 'The', 'classic'),
#  ('The', 'classic', 'universal'),
#  ('classic', 'universal', 'approximation'),
#  ('universal', 'approximation', 'theorem'),
#  ('approximation', 'theorem', 'concerns'),
#  ('theorem', 'concerns', 'the'),
#  ('concerns', 'the', 'capacity'),
#  ('the', 'capacity', 'of'),
#  ('capacity', 'of', 'feedforward'),
#  ('of', 'feedforward', 'neural'),
#  ('feedforward', 'neural', 'networks'),
#  ('neural', 'networks', 'with'),
#  ('networks', 'with', 'a'),
#  ('with', 'a', 'single'),
#  ('a', 'single', 'hidden'),
#  ('single', 'hidden', 'layer'),
#  ('hidden', 'layer', 'of'),
#  ('layer', 'of', 'finite'),
#  ('of', 'finite', 'size'),
#  ('finite', 'size', 'to'),
#  ('size', 'to', 'approximate'),
#  ('to', 'approximate', 'continuous'),
#  ('approximate', 'continuous', 'functions'),
#  ('continuous', 'functions', '.'),
#  ('functions', '.', 'In'),
#  ('.', 'In', '1989'),
#  ('In', '1989', ','),
#  ('1989', ',', 'the'),
#  (',', 'the', 'first'),
#  ('the', 'first', 'proof'),
#  ('first', 'proof', 'was'),
#  ('proof', 'was', 'published'),
#  ('was', 'published', 'by'),
#  ('published', 'by', 'George'),
#  ('by', 'George', 'Cybenko'),
#  ('George', 'Cybenko', 'for'),
#  ('Cybenko', 'for', 'sigmoid'),
#  ('for', 'sigmoid', 'activation'),
#  ('sigmoid', 'activation', 'functions'),
#  ('activation', 'functions', '['),
#  ('functions', '[', '18'),
#  ('[', '18', ']'),
#  ('18', ']', '['),
#  (']', '[', 'citation'),
#  ('[', 'citation', 'needed'),
#  ('citation', 'needed', ']'),
#  ('needed', ']', 'and'),
#  (']', 'and', 'was'),
#  ('and', 'was', 'generalised'),
#  ('was', 'generalised', 'to'),
#  ('generalised', 'to', 'feed-forward'),
#  ('to', 'feed-forward', 'multi-layer'),
#  ('feed-forward', 'multi-layer', 'architectures'),
#  ('multi-layer', 'architectures', 'in'),
#  ('architectures', 'in', '1991'),
#  ('in', '1991', 'by'),
#  ('1991', 'by', 'Kurt'),
#  ('by', 'Kurt', 'Hornik'),
#  ('Kurt', 'Hornik', '.'),
#  ('Hornik', '.', 'Recent'),
#  ('.', 'Recent', 'work'),
#  ('Recent', 'work', 'also'),
#  ('work', 'also', 'showed'),
#  ('also', 'showed', 'that'),
#  ('showed', 'that', 'universal'),
#  ('that', 'universal', 'approximation'),
#  ('universal', 'approximation', 'also'),
#  ('approximation', 'also', 'holds'),
#  ('also', 'holds', 'for'),
#  ('holds', 'for', 'non-bounded'),
#  ('for', 'non-bounded', 'activation'),
#  ('non-bounded', 'activation', 'functions'),
#  ('activation', 'functions', 'such'),
#  ('functions', 'such', 'as'),
#  ('such', 'as', 'the'),
#  ('as', 'the', 'rectified'),
#  ('the', 'rectified', 'linear'),
#  ('rectified', 'linear', 'unit'),
#  ('linear', 'unit', '.')]

# %% [markdown]
# ## The two popular stemming algorithms: Porter Stemmer and Lancaster Stemmer

# %%
from nltk.stem import PorterStemmer
DL_pst = PorterStemmer()

# %%
for words in DL_tokens:
    print(words + ":" + DL_pst.stem(words))
# Out:
# Deep:deep
# learning:learn
# is:is
# an:an
# artificial:artifici
# intelligence:intellig
# (:(
# AI:AI
# ):)
# function:function
# that:that
# imitates:imit
# the:the
# workings:work
# of:of
# the:the
# human:human
# brain:brain
# in:in
# processing:process
# data:data
# and:and
# creating:creat
# patterns:pattern
# for:for
# use:use
# in:in
# decision:decis
# making:make
# .:.
# Deep:deep
# learning:learn
# is:is
# a:a
# subset:subset
# of:of
# machine:machin
# learning:learn
# in:in
# artificial:artifici
# intelligence:intellig
# that:that
# has:ha
# networks:network
# capable:capabl
# of:of
# learning:learn
# unsupervised:unsupervis
# from:from
# data:data
# that:that
# is:is
# unstructured:unstructur
# or:or
# unlabeled:unlabel
# .:.
# Also:also
# known:known
# as:as
# deep:deep
# neural:neural
# learning:learn
# or:or
# deep:deep
# neural:neural
# network:network
# .:.
# Deep:deep
# neural:neural
# networks:network
# are:are
# generally:gener
# interpreted:interpret
# in:in
# terms:term
# of:of
# the:the
# universal:univers
# approximation:approxim
# theorem:theorem
# or:or
# probabilistic:probabilist
# inference:infer
# .:.
# The:the
# classic:classic
# universal:univers
# approximation:approxim
# theorem:theorem
# concerns:concern
# the:the
# capacity:capac
# of:of
# feedforward:feedforward
# neural:neural
# networks:network
# with:with
# a:a
# single:singl
# hidden:hidden
# layer:layer
# of:of
# finite:finit
# size:size
# to:to
# approximate:approxim
# continuous:continu
# functions:function
# .:.
# In:In
# 1989:1989
# ,:,
# the:the
# first:first
# proof:proof
# was:wa
# published:publish
# by:by
# George:georg
# Cybenko:cybenko
# for:for
# sigmoid:sigmoid
# activation:activ
# functions:function
# [:[
# 18:18
# ]:]
# [:[
# citation:citat
# needed:need
# ]:]
# and:and
# was:wa
# generalised:generalis
# to:to
# feed-forward:feed-forward
# multi-layer:multi-lay
# architectures:architectur
# in:in
# 1991:1991
# by:by
# Kurt:kurt
# Hornik:hornik
# .:.
# Recent:recent
# work:work
# also:also
# showed:show
# that:that
# universal:univers
# approximation:approxim
# also:also
# holds:hold
# for:for
# non-bounded:non-bound
# activation:activ
# functions:function
# such:such
# as:as
# the:the
# rectified:rectifi
# linear:linear
# unit:unit
# .:.

# %%
from nltk.stem import LancasterStemmer
DL_lancast = LancasterStemmer()
for words in DL_tokens:
    print(words + ":" + DL_lancast.stem(words))
# Out:
# Deep:deep
# learning:learn
# is:is
# an:an
# artificial:art
# intelligence:intellig
# (:(
# AI:ai
# ):)
# function:funct
# that:that
# imitates:imit
# the:the
# workings:work
# of:of
# the:the
# human:hum
# brain:brain
# in:in
# processing:process
# data:dat
# and:and
# creating:cre
# patterns:pattern
# for:for
# use:us
# in:in
# decision:decid
# making:mak
# .:.
# Deep:deep
# learning:learn
# is:is
# a:a
# subset:subset
# of:of
# machine:machin
# learning:learn
# in:in
# artificial:art
# intelligence:intellig
# that:that
# has:has
# networks:network
# capable:cap
# of:of
# learning:learn
# unsupervised:unsuperv
# from:from
# data:dat
# that:that
# is:is
# unstructured:unstruct
# or:or
# unlabeled:unlabel
# .:.
# Also:also
# known:known
# as:as
# deep:deep
# neural:neur
# learning:learn
# or:or
# deep:deep
# neural:neur
# network:network
# .:.
# Deep:deep
# neural:neur
# networks:network
# are:ar
# generally:gen
# interpreted:interpret
# in:in
# terms:term
# of:of
# the:the
# universal:univers
# approximation:approxim
# theorem:theorem
# or:or
# probabilistic:prob
# inference:inf
# .:.
# The:the
# classic:class
# universal:univers
# approximation:approxim
# theorem:theorem
# concerns:concern
# the:the
# capacity:capac
# of:of
# feedforward:feedforward
# neural:neur
# networks:network
# with:with
# a:a
# single:singl
# hidden:hid
# layer:lay
# of:of
# finite:finit
# size:siz
# to:to
# approximate:approxim
# continuous:continu
# functions:funct
# .:.
# In:in
# 1989:1989
# ,:,
# the:the
# first:first
# proof:proof
# was:was
# published:publ
# by:by
# George:georg
# Cybenko:cybenko
# for:for
# sigmoid:sigmoid
# activation:act
# functions:funct
# [:[
# 18:18
# ]:]
# [:[
# citation:cit
# needed:nee
# ]:]
# and:and
# was:was
# generalised:gen
# to:to
# feed-forward:feed-forward
# multi-layer:multi-layer
# architectures:architect
# in:in
# 1991:1991
# by:by
# Kurt:kurt
# Hornik:hornik
# .:.
# Recent:rec
# work:work
# also:also
# showed:show
# that:that
# universal:univers
# approximation:approxim
# also:also
# holds:hold
# for:for
# non-bounded:non-bounded
# activation:act
# functions:funct
# such:such
# as:as
# the:the
# rectified:rect
# linear:linear
# unit:unit
# .:.

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
DL_Lem=WordNetLemmatizer()

for words in DL_tokens:
    print(words+ ":" +DL_Lem.lemmatize(words))
# Out:
# Deep:Deep
# learning:learning
# is:is
# an:an
# artificial:artificial
# intelligence:intelligence
# (:(
# AI:AI
# ):)
# function:function
# that:that
# imitates:imitates
# the:the
# workings:working
# of:of
# the:the
# human:human
# brain:brain
# in:in
# processing:processing
# data:data
# and:and
# creating:creating
# patterns:pattern
# for:for
# use:use
# in:in
# decision:decision
# making:making
# .:.
# Deep:Deep
# learning:learning
# is:is
# a:a
# subset:subset
# of:of
# machine:machine
# learning:learning
# in:in
# artificial:artificial
# intelligence:intelligence
# that:that
# has:ha
# networks:network
# capable:capable
# of:of
# learning:learning
# unsupervised:unsupervised
# from:from
# data:data
# that:that
# is:is
# unstructured:unstructured
# or:or
# unlabeled:unlabeled
# .:.
# Also:Also
# known:known
# as:a
# deep:deep
# neural:neural
# learning:learning
# or:or
# deep:deep
# neural:neural
# network:network
# .:.
# Deep:Deep
# neural:neural
# networks:network
# are:are
# generally:generally
# interpreted:interpreted
# in:in
# terms:term
# of:of
# the:the
# universal:universal
# approximation:approximation
# theorem:theorem
# or:or
# probabilistic:probabilistic
# inference:inference
# .:.
# The:The
# classic:classic
# universal:universal
# approximation:approximation
# theorem:theorem
# concerns:concern
# the:the
# capacity:capacity
# of:of
# feedforward:feedforward
# neural:neural
# networks:network
# with:with
# a:a
# single:single
# hidden:hidden
# layer:layer
# of:of
# finite:finite
# size:size
# to:to
# approximate:approximate
# continuous:continuous
# functions:function
# .:.
# In:In
# 1989:1989
# ,:,
# the:the
# first:first
# proof:proof
# was:wa
# published:published
# by:by
# George:George
# Cybenko:Cybenko
# for:for
# sigmoid:sigmoid
# activation:activation
# functions:function
# [:[
# 18:18
# ]:]
# [:[
# citation:citation
# needed:needed
# ]:]
# and:and
# was:wa
# generalised:generalised
# to:to
# feed-forward:feed-forward
# multi-layer:multi-layer
# architectures:architecture
# in:in
# 1991:1991
# by:by
# Kurt:Kurt
# Hornik:Hornik
# .:.
# Recent:Recent
# work:work
# also:also
# showed:showed
# that:that
# universal:universal
# approximation:approximation
# also:also
# holds:hold
# for:for
# non-bounded:non-bounded
# activation:activation
# functions:function
# such:such
# as:a
# the:the
# rectified:rectified
# linear:linear
# unit:unit
# .:.

# %% [markdown]
# ## Remove Stopwords from the text

# %%
import re
pattern=re.compile(r'[-;,:.!?0-9()|]')

# %%
text_pattern=[]
for words in DL_tokens:
    text=pattern.sub("",words)
    if len(words)>0:
        text_pattern.append(text)
text_pattern
# Out:
# ['Deep',
#  'learning',
#  'is',
#  'an',
#  'artificial',
#  'intelligence',
#  '',
#  'AI',
#  '',
#  'function',
#  'that',
#  'imitates',
#  'the',
#  'workings',
#  'of',
#  'the',
#  'human',
#  'brain',
#  'in',
#  'processing',
#  'data',
#  'and',
#  'creating',
#  'patterns',
#  'for',
#  'use',
#  'in',
#  'decision',
#  'making',
#  '',
#  'Deep',
#  'learning',
#  'is',
#  'a',
#  'subset',
#  'of',
#  'machine',
#  'learning',
#  'in',
#  'artificial',
#  'intelligence',
#  'that',
#  'has',
#  'networks',
#  'capable',
#  'of',
#  'learning',
#  'unsupervised',
#  'from',
#  'data',
#  'that',
#  'is',
#  'unstructured',
#  'or',
#  'unlabeled',
#  '',
#  'Also',
#  'known',
#  'as',
#  'deep',
#  'neural',
#  'learning',
#  'or',
#  'deep',
#  'neural',
#  'network',
#  '',
#  'Deep',
#  'neural',
#  'networks',
#  'are',
#  'generally',
#  'interpreted',
#  'in',
#  'terms',
#  'of',
#  'the',
#  'universal',
#  'approximation',
#  'theorem',
#  'or',
#  'probabilistic',
#  'inference',
#  '',
#  'The',
#  'classic',
#  'universal',
#  'approximation',
#  'theorem',
#  'concerns',
#  'the',
#  'capacity',
#  'of',
#  'feedforward',
#  'neural',
#  'networks',
#  'with',
#  'a',
#  'single',
#  'hidden',
#  'layer',
#  'of',
#  'finite',
#  'size',
#  'to',
#  'approximate',
#  'continuous',
#  'functions',
#  '',
#  'In',
#  '',
#  '',
#  'the',
#  'first',
#  'proof',
#  'was',
#  'published',
#  'by',
#  'George',
#  'Cybenko',
#  'for',
#  'sigmoid',
#  'activation',
#  'functions',
#  '[',
#  '',
#  ']',
#  '[',
#  'citation',
#  'needed',
#  ']',
#  'and',
#  'was',
#  'generalised',
#  'to',
#  'feedforward',
#  'multilayer',
#  'architectures',
#  'in',
#  '',
#  'by',
#  'Kurt',
#  'Hornik',
#  '',
#  'Recent',
#  'work',
#  'also',
#  'showed',
#  'that',
#  'universal',
#  'approximation',
#  'also',
#  'holds',
#  'for',
#  'nonbounded',
#  'activation',
#  'functions',
#  'such',
#  'as',
#  'the',
#  'rectified',
#  'linear',
#  'unit',
#  '']

# %%
len(text_pattern)
# Out:
# 164

# %%
from nltk.corpus import stopwords

# %%
pattern_1 = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
DeepLearning_new = pattern.sub('', DeepLearning)
DeepLearning_new
# Out:
# 'Deep learning is an artificial intelligence AI function that imitates the workings of the human brain in processing data and creating patterns for use in decision making Deep learning is a subset of machine learning in artificial intelligence that has networks capable of learning unsupervised from data that is unstructured or unlabeled \nAlso known as deep neural learning or deep neural network \n\nDeep neural networks are generally interpreted in terms of the universal approximation theorem or probabilistic inference The classic universal approximation theorem concerns the capacity of feedforward neural networks with a single hidden layer of finite size to approximate continuous functions In  the first proof was published by George Cybenko for sigmoid activation functions[][citation needed] and was generalised to feedforward multilayer architectures \nin  by Kurt Hornik Recent work also showed that universal approximation also holds for nonbounded activation functions such as the rectified linear unit'

# %%
len(DeepLearning_new)
# Out:
# 1013

# %%
DL_tokens_n= word_tokenize(DeepLearning_new)

# %% [markdown]
# ## Parts-Of-Speech (POS) tagging
# To identify whether the word is a noun, adjective, verb, and so on.

# %%
nltk.download('averaged_perceptron_tagger')
for token in DL_tokens_n:
    print(nltk.pos_tag([token]))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\maede\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Deep', 'JJ')]
# [('learning', 'VBG')]
# [('is', 'VBZ')]
# [('an', 'DT')]
# [('artificial', 'JJ')]
# [('intelligence', 'NN')]
# [('AI', 'NN')]
# [('function', 'NN')]
# [('that', 'IN')]
# [('imitates', 'NNS')]
# [('the', 'DT')]
# [('workings', 'NNS')]
# [('of', 'IN')]
# [('the', 'DT')]
# [('human', 'NN')]
# [('brain', 'NN')]
# [('in', 'IN')]
# [('processing', 'NN')]
# [('data', 'NNS')]
# [('and', 'CC')]
# [('creating', 'VBG')]
# [('patterns', 'NNS')]
# [('for', 'IN')]
# [('use', 'NN')]
# [('in', 'IN')]
# [('decision', 'NN')]
# [('making', 'VBG')]
# [('Deep', 'JJ')]
# [('learning', 'VBG')]
# [('is', 'VBZ')]
# [('a', 'DT')]
# [('subset', 'NN')]
# [('of', 'IN')]
# [('machine', 'NN')]
# [('learning', 'VBG')]
# [('in', 'IN')]
# [('artificial', 'JJ')]
# [('intelligence', 'NN')]
# [('that', 'IN')]
# [('has', 'VBZ')]
# [('networks', 'NNS')]
# [('capable', 'JJ')]
# [('of', 'IN')]
# [('learning', 'VBG')]
# [('unsupervised', 'JJ')]
# [('from', 'IN')]
# [('data', 'NNS')]
# [('that', 'IN')]
# [('is', 'VBZ')]
# [('unstructured', 'JJ')]
# [('or', 'CC')]
# [('unlabeled', 'JJ')]
# [('Also', 'RB')]
# [('known', 'VBN')]
# [('as', 'IN')]
# [('deep', 'NN')]
# [('neural', 'JJ')]
# [('learning', 'VBG')]
# [('or', 'CC')]
# [('deep', 'NN')]
# [('neural', 'JJ')]
# [('network', 'NN')]
# [('Deep', 'JJ')]
# [('neural', 'JJ')]
# [('networks', 'NNS')]
# [('are', 'VBP')]
# [('generally', 'RB')]
# [('interpreted', 'VBN')]
# [('in', 'IN')]
# [('terms', 'NNS')]
# [('of', 'IN')]
# [('the', 'DT')]
# [('universal', 'NN')]
# [('approximation', 'NN')]
# [('theorem', 'NN')]
# [('or', 'CC')]
# [('probabilistic', 'JJ')]
# [('inference', 'NN')]
# [('The', 'DT')]
# [('classic', 'JJ')]
# [('universal', 'NN')]
# [('approximation', 'NN')]
# [('theorem', 'NN')]
# [('concerns', 'NNS')]
# [('the', 'DT')]
# [('capacity', 'NN')]
# [('of', 'IN')]
# [('feedforward', 'NN')]
# [('neural', 'JJ')]
# [('networks', 'NNS')]
# [('with', 'IN')]
# [('a', 'DT')]
# [('single', 'JJ')]
# [('hidden', 'NN')]
# [('layer', 'NN')]
# [('of', 'IN')]
# [('finite', 'NN')]
# [('size', 'NN')]
# [('to', 'TO')]
# [('approximate', 'NN')]
# [('continuous', 'JJ')]
# [('functions', 'NNS')]
# [('In', 'IN')]
# [('the', 'DT')]
# [('first', 'RB')]
# [('proof', 'NN')]
# [('was', 'VBD')]
# [('published', 'VBN')]
# [('by', 'IN')]
# [('George', 'NNP')]
# [('Cybenko', 'NN')]
# [('for', 'IN')]
# [('sigmoid', 'NN')]
# [('activation', 'NN')]
# [('functions', 'NNS')]
# [('[', 'NN')]
# [(']', 'NN')]
# [('[', 'NN')]
# [('citation', 'NN')]
# [('needed', 'VBN')]
# [(']', 'NN')]
# [('and', 'CC')]
# [('was', 'VBD')]
# [('generalised', 'VBN')]
# [('to', 'TO')]
# [('feedforward', 'NN')]
# [('multilayer', 'NN')]
# [('architectures', 'NNS')]
# [('in', 'IN')]
# [('by', 'IN')]
# [('Kurt', 'NNP')]
# [('Hornik', 'NN')]
# [('Recent', 'NN')]
# [('work', 'NN')]
# [('also', 'RB')]
# [('showed', 'VBD')]
# [('that', 'IN')]
# [('universal', 'NN')]
# [('approximation', 'NN')]
# [('also', 'RB')]
# [('holds', 'VBZ')]
# [('for', 'IN')]
# [('nonbounded', 'VBN')]
# [('activation', 'NN')]
# [('functions', 'NNS')]
# [('such', 'JJ')]
# [('as', 'IN')]
# [('the', 'DT')]
# [('rectified', 'VBN')]
# [('linear', 'NN')]
# [('unit', 'NN')]

# %%
#to import spacy: run the following command in the Command Line tab in path 
#C:\Users\maede\AppData\Local\Programs\Python\Python38\Scripts>
#pip3 install spacy scikit-learn seaborn
import spacy
from spacy import displacy

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
my_text=nlp(DeepLearning)

# display tokens with their POS tags written just below them
#Visit https://nlp.stanford.edu/software/dependencies_manual.pdf to discover the list of relationships with their descriptions
displacy.render(my_text,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f87c7b339eae47899a95c71d9799bab7-0" class="displacy" width="27000" height="1099.5" direction="ltr" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Deep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">intelligence (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">AI)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">function</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">imitates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">workings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">human</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">brain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">creating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">patterns</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">decision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">making.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Deep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">a</tspan>
#     <tspan clas

# %% [markdown]
# ## Split the text into meaningful chunks (sentences)
# The PunktSentenceTokenizer is an unsupervised trainable model. This means it can be trained on unlabeled text. An Unlabeled text is a written work that is not split into sentences.

# %%
from nltk.corpus import state_union
nltk.download('state_union')
from nltk.tokenize import PunktSentenceTokenizer

train = state_union.raw("2005-GWBush.txt")
test = state_union.raw("2006-GWBush.txt")

sent_tokenizer = PunktSentenceTokenizer(train)
tokenized = sent_tokenizer.tokenize(test)

def preprocess():
    try:
        for i in tokenized:
            token = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(token)
            chunk_Gram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunk_Parser = nltk.RegexpParser(chunk_Gram)
            chunked = chunk_Parser.parse(tagged)
            
            print(chunked)
            for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
                print(subtree)

            chunked.draw()

    except Exception as e:
        print(str(e))

preprocess()
# Out:
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\maede\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (Chunk ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk THE/NNP UNION/NNP January/NNP)
#   31/CD
#   ,/,
#   2006/CD
#   (Chunk THE/NNP PRESIDENT/NNP)
#   :/:
#   (Chunk Thank/NNP)
#   you/PRP
#   all/DT
#   ./.)
# (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP)
# (Chunk ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP January/NNP)
# (Chunk THE/NNP PRESIDENT/NNP)
# (Chunk Thank/NNP)
# (S
#   (Chunk Mr./NNP Speaker/NNP)
#   ,/,
#   (Chunk Vice/NNP President/NNP Cheney/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   the/DT
#   (Chunk Supreme/NNP Court/NNP)
#   and/CC
#   diplomatic/JJ
#   corps/NN
#   ,/,
#   distinguished/JJ
#   guests/NNS
#   ,/,
#   and/CC
#   fellow/JJ
#   citizens/NNS
#   :/:
#   Today/VB
#   our/PRP$
#   nation/NN
#   lost/VBD
#   a/DT
#   beloved/VBN
#   ,/,
#   graceful/JJ
#   ,/,
#   courageous/JJ
#   woman/NN
#   who/WP
#   (Chunk called/VBD America/NNP)
#   to/TO
#   its/PRP$
#   founding/NN
#   ideals/NNS
#   and/CC
#   carried/VBD
#   on/IN
#   a/DT
#   noble/JJ
#   dream/NN
#   ./.)
# (Chunk Mr./NNP Speaker/NNP)
# (Chunk Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk called/VBD America/NNP)
# (S
#   Tonight/NN
#   we/PRP
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   glad/JJ
#   reunion/NN
#   with/IN
#   the/DT
#   husband/NN
#   who/WP
#   was/VBD
#   taken/VBN
#   so/RB
#   long/RB
#   ago/RB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   for/IN
#   the/DT
#   good/JJ
#   life/NN
#   of/IN
#   (Chunk Coretta/NNP Scott/NNP King/NNP)
#   ./.)
# (Chunk Coretta/NNP Scott/NNP King/NNP)

# %%
# Test the tokenizer on a piece of text
sentences = "Prof. Johnson accepted to accompany Ms. Smith to the theatre. They spent enjoyable time together."
 
print(sent_tokenizer.tokenize(sentences))
# Out:
# ['Prof.', 'Johnson accepted to accompany Ms.', 'Smith to the theatre.', 'They spent enjoyable time together.']

# %% [markdown]
# ## Add more abbreviations

# %%
# List of the learned abbreviations from the trainin text
print(sent_tokenizer._params.abbrev_types)
# Out:
# {'mr', 'p.m', 'w'}

# %%
#Add more abbreviations
sent_tokenizer._params.abbrev_types.add('ms')
print(sent_tokenizer._params.abbrev_types)
print(sent_tokenizer.tokenize(sentences))
# Out:
# {'mr', 'p.m', 'ms', 'w'}
# ['Prof.', 'Johnson accepted to accompany Ms. Smith to the theatre.', 'They spent enjoyable time together.']

# %%
from nltk.tokenize.punkt import PunktParameters
punktP = PunktParameters()
punktP.abbrev_types = set(['mr', 'mrs', 'ms', 'dr', 'prof'])
sentence_split = PunktSentenceTokenizer(punktP)
new_text = sentence_split.tokenize(sentences)
new_text
# Out:
# ['Prof. Johnson accepted to accompany Ms. Smith to the theatre.',
#  'They spent enjoyable time together.']

# %% [markdown]
# ## Named Entity Recognition

# %%
My_doc=nlp(DeepLearning)

# Print the named entities
print(My_doc.ents)
# Out:
# (AI, 1989, first, George Cybenko, 1991, Kurt Hornik)

# %%
# Print types of entities:

# PERSON : People, including fictional.
# NORP : Nationalities or religious or political groups.
# FAC : Buildings, airports, highways, bridges, etc.
# ORG : Companies, agencies, institutions, etc.
# GPE : Countries, cities, states.
# LOC : Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT : Objects, vehicles, foods, etc. (Not services.)
# EVENT : Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART : Titles of books, songs, etc.
# LAW : Named documents made into laws.
# LANGUAGE : Any named language.
# DATE : Absolute or relative dates or periods.
# TIME : Times smaller than a day.
# PERCENT : Percentage, including ”%“.
# MONEY : Monetary values, including unit.
# QUANTITY : Measurements, as of weight or distance.
# ORDINAL : “first”, “second”, etc.
# CARDINAL : Numerals that do not fall under another type.

for entity in My_doc.ents:
  print(entity.text, '( start_char=', entity.start_char, ', end_char=', entity.end_char, ')', '---> ',entity.label_)
# Out:
# AI ( start_char= 45 , end_char= 47 ) --->  ORG
# 1989 ( start_char= 706 , end_char= 710 ) --->  DATE
# first ( start_char= 716 , end_char= 721 ) --->  ORDINAL
# George Cybenko ( start_char= 745 , end_char= 759 ) --->  PERSON
# 1991 ( start_char= 880 , end_char= 884 ) --->  DATE
# Kurt Hornik ( start_char= 888 , end_char= 899 ) --->  PERSON
